# %%
liste = ["a", "b", "c"]
for i in liste:
    print(i)
    print("==========")

for i, val in enumerate(liste, 0):
    print(f"index = {i}, valeur = {val}")
# Out:
# a
# ...
# b
# ...
# c
# ...
# index = 0, valeur = a
# index = 1, valeur = b
# index = 2, valeur = c
